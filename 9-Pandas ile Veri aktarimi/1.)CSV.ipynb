# %% [markdown]
# # CSV (Comma-separated values)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Dataframe oluşturup dışa ve içe aktarmak için kullanacağız.

# %%
data = np.array((['Ayşe','Ahmet','Fatma','Ali'],
                 [75,   70,  65,  95],
                 [100,  70,  75,  100]))

# %%
df = pd.DataFrame(data,columns=['Bir','İki','Üç','Dört'],index=['İsim','Vize','Final'])
df
# Out:
#         Bir    İki     Üç Dört
# İsim   Ayşe  Ahmet  Fatma  Ali
# Vize     75     70     65   95
# Final   100     70     75  100

# %% [markdown]
# ### Dışarı aktarmak

# %%
df.to_csv('example.csv')

# %% [markdown]
# ### İçeri aktarmak

# %%
veri = pd.read_csv('sample_dataset.csv')

# %%
veri
# Out:
#        Customer ID       Name    Surname Gender   Birthdate  \
# 0           752858       Sean  Rodriguez      F  2002-10-20
# 1            26381   Michelle     Phelps    NaN  1985-10-24
# 2           305449      Jacob   Williams      M  1981-10-25
# 3           988259     Nathan     Snyder      M  1977-10-26
# 4           764762    Crystal      Knapp      F  1951-11-02
# ...            ...        ...        ...    ...         ...
# 49995       891845  Christine      Leach      F  1997-10-21
# 49996       800560       Anna      Allen      F  1999-10-21
# 49997       133285     Nicole   Franklin      M  1979-10-26
# 49998       616122      Maria     Keller      M  1981-10-25
# 49999       832184      Billy     Walker      F  1958-10-31
#
#        Transaction Amount        Date                 Merchant Name  \
# 0                   35.47  2023-04-03                 Smith-Russell
# 1                 2552.72  2023-07-17        Peck, Spence and Young
# ...

# %%
veri = pd.read_csv('sample_dataset.csv',index_col=0)

# %%
veri
# Out:
#                   Name    Surname Gender   Birthdate  Transaction Amount  \
# Customer ID
# 752858            Sean  Rodriguez      F  2002-10-20               35.47
# 26381         Michelle     Phelps    NaN  1985-10-24             2552.72
# 305449           Jacob   Williams      M  1981-10-25              115.97
# 988259          Nathan     Snyder      M  1977-10-26               11.31
# 764762         Crystal      Knapp      F  1951-11-02               62.21
# ...                ...        ...    ...         ...                 ...
# 891845       Christine      Leach      F  1997-10-21              108.74
# 800560            Anna      Allen      F  1999-10-21              133.66
# 133285          Nicole   Franklin      M  1979-10-26              464.29
# 616122           Maria     Keller      M  1981-10-25              472.57
# 832184           Billy     Walker      F  1958-10-31              270.67
#
#                    Date                 Merchant Name     Category
# ...
