# %% [markdown]
# # Matplotlib

# %% [markdown]
# Veri görselleştirmesini kolaylaştıran bir kütüphanedir.

# %% [markdown]
# #### Kütüphaneyi çağırmak

# %% [markdown]
# NumPy için np, Pandas için pd kısaltması kısayolunu kullandığımız gibi, Matplotlib kütüphanesi için bazı standart kısayollar kullanacağız:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# **plt** arayüzü, bu bölüm boyunca göreceğimiz gibi **en sık ** kullanacağımızdır.

# %% [markdown]
# #### Notebook da görüntülemek için

# %%
# %matplotlib inline

# %% [markdown]
# #### Stilleri Ayarlama

# %% [markdown]
# Figürlerimiz için uygun estetik tarzları seçmek için **plt.style**  kullanacağız.

# %%
import numpy as np
deger = np.arange(0,10)

# %%
plt.style.use('classic')
plt.plot(deger)
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(deger)
plt.show()

# %% [markdown]
# #### Görseli kaydetmek

# %%
plt.style.use('classic')#stil değiştirdik

x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

plt.show()

# %%
fig.savefig('first_figure.png')
